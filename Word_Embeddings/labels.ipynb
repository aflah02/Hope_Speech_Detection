# %%
import numpy as np
import string
import os
import pandas as pd

# %% [markdown]
# ## Loading Data

# %%
parent_dir = os.path.join(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
folder_path = 'Data\PreprocessedData'
net_path = os.path.join(parent_dir, folder_path)
aug_path = 'Data\AugmentedData'
net_aug_path = os.path.join(parent_dir, aug_path)

# %%
df_train_english = pd.read_csv(os.path.join(net_path, 'english_train_preprocess.csv'))
df_dev_english = pd.read_csv(os.path.join(net_path, 'english_dev_preprocess.csv'))
df_test_english = pd.read_csv(os.path.join(net_path, 'english_test_preprocess.csv'))
df_train_augmented = pd.read_csv(os.path.join(net_aug_path, 'english_train_augmented.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Desktop\ML Group Project\Word_Embeddings\labels.ipynb Cell 4 in <module>
#       <a href='vscode-notebook-cell:/d%3A/Desktop/ML%20Group%20Project/Word_Embeddings/labels.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df_dev_english = pd.read_csv(os.path.join(net_path, 'english_dev_preprocess.csv'))
#       <a href='vscode-notebook-cell:/d%3A/Desktop/ML%20Group%20Project/Word_Embeddings/labels.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> df_test_english = pd.read_csv(os.path.join(net_path, 'english_test_preprocess.csv'))
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/ML%20Group%20Project/Word_Embeddings/labels.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> df_train_augmented = pd.read_csv('Data\AugmentedData\english_train_augmented.csv')
#
# ...

# %%
train_labels = df_train_english['label'].values
dev_labels = df_dev_english['label'].values
test_labels = df_test_english['label'].values
augmented_train_labels = df_train_augmented['label'].values

# %%
save_path = os.path.join(parent_dir, 'Word_Embeddings\Pre Computed Word Embeddings')

# %%
np.save(os.path.join(save_path, 'train_labels'), train_labels)
np.save(os.path.join(save_path, 'dev_labels'), dev_labels)
np.save(os.path.join(save_path, 'test_labels'), test_labels)
np.save(os.path.join(save_path, 'augmented_train_labels'), augmented_train_labels)
